# %%
import matplotlib.pyplot as plt

# %%
years = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]

kohli = [1220, 1050, 1380, 2450, 2300, 2735, 2100, 1350, 1650, 1780, 2150, 1980]
rohit = [980, 1350, 1250, 1750, 1850, 2250, 2100, 1400, 1620, 1880, 1750, 1600]
sehwag= [780, 520, 300, 120, 0, 0, 0, 0, 0, 0, 0, 0]
sachin= [840, 400, 100, 0, 0, 0, 0, 0, 0, 0, 0, 0]
dhawan= [960, 1150, 1380, 1680, 1420, 1200, 980, 620, 800, 1050, 850, 770]

# %%
plt.plot(years,kohli,"r^:",label="Virat")
plt.plot(years,rohit,"b4:",label="rohit")
plt.plot(years,sehwag,"gp:",label="sehwag")
plt.plot(years,sachin,"rh--",label="sachin")
plt.plot(years,dhawan,"b|:",label="dhawan")
plt.xlabel("Years")
plt.ylabel("Score")
plt.grid(True)
plt.tight_layout()
plt.legend()
plt.show()
